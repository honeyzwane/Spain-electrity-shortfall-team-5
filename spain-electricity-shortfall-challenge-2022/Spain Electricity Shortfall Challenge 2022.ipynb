# %% [markdown]
# ## Spain Electricity Shortfall Challenge 2022
#
#
#
#
# *Electricity shortfalls are a new problem that many countries face. this issue goes on to affect the very economy of these countries. from the smallest business to the large ecomomy driving forces of a country. In todays world. the importance of electricity cannot be overstated. Almost all of the best innovation run on one form or another of electricity.
# Spain in light of its recent troubles with electricity shortfalls, has sought to diverge more into the renewable power sources. with this in mind, we have been tasked In this project to model the shortfall between the energy generated by means of fossil fuels and various renewable sources - for the country of Spain. The daily shortfall, which will be referred to as the target variable, will be modelled as a function of various city-specific weather features such as pressure,  wind speed, humidity, etc.*
#
# As team 5 of the kaggle challenge, comprising of; Honey Zwane, Itumeleng Kesebonye, Tochukwu Agodi and Collins Kgooho. we have set out to undertake this Kaggle challenge.

# %% [markdown]
# # *Data analysis and model creation.*

# %% [markdown]
# ## Task 1
# **Exploratory Data Analysis**

# %%
import pandas as pd
TestFile = pd.read_csv('df_test.csv')

# %%
import pandas as pd
TrainFile = pd.read_csv('df_train.csv')

# %%
import pandas as pd
TrainFile = pd.read_csv('df_train.csv')

# %%
import pandas as pd
SampleFile = pd.read_csv('sample_submission_load_shortfall (1).csv')
navalues= 'n/a'
parse_date= ['last update']

# %% [markdown]
# ## Task 2
# **Feature engineering**

# %% [markdown]
# ## Task 3
# **Model creation**

# %% [markdown]
# # Model deployment.

# %% [markdown]
# # *Discussion.*

# %% [markdown]
# # *Conclussion.*
